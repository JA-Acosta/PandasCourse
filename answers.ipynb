# %% [markdown]
# # Pandas py practice
# Author: Joe Acosta
# Date: 07/18/2025
#
# Day 1: Creating yaml file to automatically create Conda env, learn how to use Conda and how to download MiniConda
#
# Day 2: Start Course and Practice Recreating Conda env
#
# Day 3: Reviewed Pandas info -> Pandas is built on NumPy and uses MatPlotLib to visualize the data

# %% [markdown]
# List the imports required to get the titanic dataset and load the dataset

# %%
# Imports
import pandas as pd
import seaborn as sns

# %%
# Gets the titanic dataset from the sns dataset
titanic = sns.load_dataset('titanic')

# %% [markdown]
# Check the data types for the dataset and its columns

# %%
# Gets the data type of the titanic dataset to verify if it's pandas dfS
print(type(titanic))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# get the series data types
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# Get the DataFrame information

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# How many people were on the titanic?

# %%
titanic.shape # or len(titanic)
# Out:
# (891, 15)

# %% [markdown]
# Create a df of all adult males that were alone

# %%
alone_males=titanic.loc[(titanic.alone == True) & (titanic.adult_male == True)]

# %% [markdown]
# How many alone males were in first class

# %%
(alone_males['class'] == 'First').sum()
# Out:
# np.int64(75)

# %% [markdown]
# What is the average price for alone males, max, min?

# %%
alone_males.fare.describe()
# Out:
# count    410.000000
# mean      16.708299
# std       32.003090
# min        0.000000
# 25%        7.750000
# 50%        8.050000
# 75%       13.500000
# max      512.329200
# Name: fare, dtype: float64

# %% [markdown]
# Which alone males paid more than the average titanic price?

# %%
alone_males.loc[alone_males.fare > titanic.fare.mean()]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 23          1       1  male  28.0      0      0   35.5000        S   First
# 55          1       1  male   NaN      0      0   35.5000        S   First
# 72          0       2  male  21.0      0      0   73.5000        S  Second
# 74          1       3  male  32.0      0      0   56.4958        S   Third
# 83          0       1  male  28.0      0      0   47.1000        S   First
# 96          0       1  male  71.0      0      0   34.6542        C   First
# 110         0       1  male  47.0      0      0   52.0000        S   First
# 139         0       1  male  24.0      0      0   79.2000        C   First
# 169         0       3  male  28.0      0      0   56.4958        S   Third
# 170         0       1  male  61.0      0      0   33.5000        S   First
# 185         0       1  male   NaN      0      0   50.0000        S   First
# 339         0       1  male  45.0      0      0   35.5000        S   First
# 351         0       1  male   NaN      0      0   35.0000        S   First
# 373         0       1  male  22.0      0      0  135.6333        C   First
# 385         0       2  male  18.0      0      0   73.5000        S  Second
# 462         0       1  male  47.0      0      0   38.5000        S   First
# 475         0       1  male   NaN      0      0   52.0000        S   First
# 493         0       1  male  71.0      0      0   49.5042        C   First
# 509         1       3  male  26.0      0      0   56.4958        S   Third
# 515         0       1  male  47.0      0      0   34.0208        S   First
# 527         0       1  male   NaN      0      0  221.7792        S   First
# 557         0       1  male   NaN      0      0  227.5250        C   First
# 583         0       1  male  36.0      0      0   40.1250        C   First
# 602         0       1  male   NaN      0      0   42.4000        S   First
# 625         0       1  male  61.0      0      0   32.3208        S   First
# 643         1       3  male   NaN      0      0   56.4958        S   Third
# 647         1       1  male  56.0      0      0   35.5000        C   First
# 681         1       1  male  27.0      0      0   76.7292        C   First
# 692         1       3  male   NaN      0      0   56.4958        S   Third
# 737         1       1  male  35.0      0      0  512.3292        C   First
# 766         0       1  male   NaN      0      0   39.6000        C   First
# 789         0       1  male  46.0      0      0   79.2000        C   First
# 826         0       3  male   NaN      0      0   56.4958        S   Third
# 838         1       3  male  32.0      0      0   56.4958        S   Third
# 867         0       1  male  31.0      0      0   50.4958        S   First
#
#      who  adult_male deck  embark_town alive  alone
# 6    man        True    E  Southampton    no   True
# 23   man        True    A  Southampton   yes   True
# 55   man        True    C  Southampton   yes   True
# 72   man        True  NaN  Southampton    no   True
# 74   man        True  NaN  Southampton   yes   True
# 83   man        True  NaN  Southampton    no   True
# 96   man        True    A    Cherbourg    no   True
# 110  man        True    C  Southampton    no   True
# 139  man        True    B    Cherbourg    no   True
# 169  man        True  NaN  Southampton    no   True
# 170  man        True    B  Southampton    no   True
# 185  man        True    A  Southampton    no   True
# 339  man        True  NaN  Southampton    no   True
# 351  man        True    C  Southampton    no   True
# 373  man        True  NaN    Cherbourg    no   True
# 385  man        True  NaN  Southampton    no   True
# 462  man        True    E  Southampton    no   True
# 475  man        True    A  Southampton    no   True
# 493  man        True  NaN    Cherbourg    no   True
# 509  man        True  NaN  Southampton   yes   True
# 515  man        True    D  Southampton    no   True
# 527  man        True    C  Southampton    no   True
# 557  man        True  NaN    Cherbourg    no   True
# 583  man        True    A    Cherbourg    no   True
# 602  man        True  NaN  Southampton    no   True
# 625  man        True    D  Southampton    no   True
# 643  man        True  NaN  Southampton   yes   True
# 647  man        True    A    Cherbourg   yes   True
# 681  man        True    D    Cherbourg   yes   True
# 692  man        True  NaN  Southampton   yes   True
# 737  man        True    B    Cherbourg   yes   True
# 766  man        True  NaN    Cherbourg    no   True
# 789  man        True    B    Cherbourg    no   True
# 826  man        True  NaN  Southampton    no   True
# 838  man        True  NaN  Southampton   yes   True
# 867  man        True    A  Southampton    no   True

# %% [markdown]
# What are the different columns?

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# Get the Top 10 and Bottom 5

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# Get 5 random passangers

# %%
titanic.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 360         0       3    male  40.0      1      4   27.9000        S   Third
# 322         1       2  female  30.0      0      0   12.3500        Q  Second
# 219         0       2    male  30.0      0      0   10.5000        S  Second
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 14          0       3  female  14.0      0      0    7.8542        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 360    man        True  NaN  Southampton    no  False
# 322  woman       False  NaN   Queenstown   yes   True
# 219    man        True  NaN  Southampton    no   True
# 438    man        True    C  Southampton    no  False
# 14   child       False  NaN  Southampton    no   True

# %% [markdown]
# Get Single Passenger

# %%
titanic.sample()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 4         0       3  male  35.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# Get the passenger # 342's information

# %%
titanic.loc[342] # Since @ int in this case for index cal also use iloc[]
# Out:
# survived                 0
# pclass                   2
# sex                   male
# age                   28.0
# sibsp                    0
# parch                    0
# fare                  13.0
# embarked                 S
# class               Second
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 342, dtype: object

# %% [markdown]
# Was Passenger #121 an adult male?

# %%
# first checked the columns
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.loc[121, 'adult_male'] # or titanic.loc[121].adult_male
# Out:
# np.True_

# %% [markdown]
# What was the oldest passengers age?

# %%
titanic.age.max()
# Out:
# np.float64(80.0)

# %% [markdown]
# Get all statistics for the passenger ages

# %%
titanic.age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %% [markdown]
# What are the ages and sex of passengers 123, 153, and 232

# %%
titanic.loc[[123, 153, 232], ['age', 'sex']]
# Out:
#       age     sex
# 123  32.5  female
# 153  40.5    male
# 232  59.0    male

# %% [markdown]
# Order the passengers descending by age and print the results

# %%
titanic.sort_values(by='age', ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 630         1       1    male  80.0      0      0  30.0000        S  First
# 851         0       3    male  74.0      0      0   7.7750        S  Third
# 493         0       1    male  71.0      0      0  49.5042        C  First
# 96          0       1    male  71.0      0      0  34.6542        C  First
# 116         0       3    male  70.5      0      0   7.7500        Q  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 859         0       3    male   NaN      0      0   7.2292        C  Third
# 863         0       3  female   NaN      8      2  69.5500        S  Third
# 868         0       3    male   NaN      0      0   9.5000        S  Third
# 878         0       3    male   NaN      0      0   7.8958        S  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 630    man        True    A  Southampton   yes   True
# 851    man        True  NaN  Southampton    no   True
# 493    man        True  NaN    Cherbourg    no   True
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [891 rows x 15 columns]

# %% [markdown]
# Which passenger had an age of 14.5

# %%
titanic.loc[titanic.age == 14.5]
# Known as conditional selections
# This: titanic.age == 14.5 creates a bool value and when we return a bool arr to loc, will give val
# these bool arr are so tiny, that using them doesn't take a lot of mem!
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 111         0       3  female  14.5      1      0  14.4542        C  Third
#
#        who  adult_male deck embark_town alive  alone
# 111  child       False  NaN   Cherbourg    no  False

# %% [markdown]
# What were all the unique ages of the passengers

# %%
titanic.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %% [markdown]
# How many different classes did the Titanic have?

# %%
# Can just use nunique; this counts the unique number without needing to use the len(titanic['class'].unique()) to get the count
titanic['class'].nunique()
# Out:
# 3

# %% [markdown]
# How many Passengers were in each class?

# %%
titanic.groupby('class').size()

# Alternatively: titanic['class'].value_counts()

# Can also do .size() since this is a series now

# NOTE VALUE_COUNTS WILL IGNORE ALL NANS. TO GET A TRUE COUNT, USE GROUPBY
# Out:
# C:\Users\Drago\AppData\Local\Temp\ipykernel_24968\1331277213.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby('class').size()
# class
# First     216
# Second    184
# Third     491
# dtype: int64

# %% [markdown]
# What are the top 5 ages?

# %%
titanic.age.value_counts().head()
# Out:
# age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 30.0    25
# Name: count, dtype: int64

# %% [markdown]
# What percent of the passengers are represented by the top 5 ages?

# %%
titanic.age.value_counts().head().sum() / len(titanic)
# Out:
# np.float64(0.14927048260381592)

# %% [markdown]
# Who was the youngest first class passenger

# %%
titanic.loc[titanic['class'] == 'First'].sort_values(by='age', ascending=True)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 445         1       1    male   4.00      0      2   81.8583        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
# 435         1       1  female  14.00      1      2  120.0000        S  First
# ..        ...     ...     ...    ...    ...    ...       ...      ...    ...
# 766         0       1    male    NaN      0      0   39.6000        C  First
# 793         0       1    male    NaN      0      0   30.6958        C  First
# 815         0       1    male    NaN      0      0    0.0000        S  First
# 839         1       1    male    NaN      0      0   29.7000        C  First
# 849         1       1  female    NaN      1      0   89.1042        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 305  child       False    C  Southampton   yes  False
# 297  child       False    C  Southampton    no  False
# 445  child       False    A  Southampton   yes  False
# 802  child       False    B  Southampton   yes  False
# 435  child       False    B  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 766    man        True  NaN    Cherbourg    no   True
# 793    man        True  NaN    Cherbourg    no   True
# 815    man        True    B  Southampton    no   True
# 839    man        True    C    Cherbourg   yes   True
# 849  woman       False    C    Cherbourg   yes  False
#
# [216 rows x 15 columns]

# %%
# alternative if need to solve dynamically for changing data and just need the last value
# this solution will always give the lowest value for the age regardless if the data changes
titanic.loc[titanic['class'] == 'First'].age.min()
# Out:
# np.float64(0.92)

# %% [markdown]
# What was the average ticket price, the max ticket price, and the min ticket price

# %%
titanic.fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %% [markdown]
# How many passengers didn't pay for a ticket?

# %%
(titanic.fare == 0).sum()
# len(titanic.loc[titanic.fare == 0])
# Out:
# np.int64(15)

# %% [markdown]
# Assign the ticket prices high, mid, low for revenue. The category delimiters are the 1/3rd percentile and 2/3rd percentile
#
# USE A FUNCTION

# %%
# Function that assigns the quartiles
low=titanic.fare.quantile(1/3)
high=titanic.fare.quantile(2/3)

def price_category(price) :
    '''
    Assigns a low, med, or high designation given the price of a ticket. The designations are based on percentiles.
    '''
    if price <= low :
        return 'Low'
    elif price <= high :
        return 'Med'
    else :
        return 'High'

# %%
fare_category=titanic.fare.apply(price_category)
fare_category
# Out:
# 0       Low
# 1      High
# 2       Low
# 3      High
# 4       Low
#        ...
# 886     Med
# 887    High
# 888     Med
# 889    High
# 890     Low
# Name: fare, Length: 891, dtype: object

# %% [markdown]
# Get the counts given the fare categories

# %%
fare_category.value_counts()
# Out:
# fare
# Low     308
# High    295
# Med     288
# Name: count, dtype: int64

# %% [markdown]
# Who was more likely to die, people traveling alone or people traveling with others

# %%
# Checked missing data
titanic.alone.unique()
titanic.survived.unique()
# Out:
# array([0, 1])

# %%
alone_survived=titanic.groupby(['survived', 'alone']).size().unstack(fill_value=0)
alone_survived
# Out:
# alone     False  True
# survived
# 0           175    374
# 1           179    163

# %%
titanic.groupby('alone').get_group(True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [537 rows x 15 columns]

# %%
# get the totals
titanic.alone.value_counts()
# Out:
# alone
# True     537
# False    354
# Name: count, dtype: int64

# %%
alone_survived.loc[1] / titanic.alone.value_counts().sort_index()
# Out:
# alone
# False    0.505650
# True     0.303538
# dtype: float64

# %%
# This will create dataframes for each group

# %%
titanic.groupby('alone')['survived'].mean()
# Out:
# alone
# False    0.505650
# True     0.303538
# Name: survived, dtype: float64

# %% [markdown]
# of the five people with the most expensive tickets, how many survived, what class were they in, and how much did they pay?

# %%
exp_tickets=titanic.fare.sort_values(ascending=False).head(10)

# %%
# This doesn't make sense since this is using one df to query another df so fixed it
# titanic.loc[exp_tickets.index, ['survived', 'class', 'fare']]
# Fixed the answer to not query a df with another df
exp_tickets[['survived', 'class', 'fare']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 4
#       1 # This doesn't make sense since this is using one df to query another df so fixed it
#       2 # titanic.loc[exp_tickets.index, ['survived', 'class', 'fare']]
#       3 # Fixed the answer to not query a df with another df
# ----> 4 exp_tickets[['survived', 'class', 'fare']]
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\series.py:1162, in Series.__getitem__(self, key)
#    1159     key = np.asarray(key, dtype=bool)
#    1160     return self._get_rows_with_mask(key)
# -> 1162 return self._get_with(key)
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\series.py:1203, in Series._get_with(self, key)
#    1200         return self.iloc[key]
#    1202 # handle the dup indexing case GH#4246
# -> 1203 return self.loc[key]
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Drago\miniconda3\envs\pandas_practice\lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['survived', 'class', 'fare'], dtype='object')] are in the [index]"

# %% [markdown]
# What's the total cost of all passenger tickets

# %%
# This is using the sum function available to pandas Series
titanic.fare.sum()
# Out:
# np.float64(28693.9493)

# %% [markdown]
# The oldest passenger was 80, what class did they belong to

# %%
titanic.loc[titanic.age == titanic.age.max()]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.0        S  First  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True

# %% [markdown]
# What was the oldest passengers ID?

# %%
titanic.age.idxmax()
# Out:
# 630

# %% [markdown]
# Create a series for ticket price with a name

# %%
fare_series=pd.Series(titanic.fare, name='Ticket Prices')

# %% [markdown]
# What is the data type for the series ticket price?

# %%
fare_series.dtype
# Out:
# dtype('float64')

# %% [markdown]
# How Many people in each class survived and what percentages in each class survived?

# %%
survival = titanic.groupby(['survived', 'class']).size().unstack(fill_value=0)
survival.loc[1] / survival.sum()
# Out:
# C:\Users\Drago\AppData\Local\Temp\ipykernel_15404\1622123742.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival = titanic.groupby(['survived', 'class']).size().unstack(fill_value=0)
# class
# First     0.629630
# Second    0.472826
# Third     0.242363
# dtype: float64
